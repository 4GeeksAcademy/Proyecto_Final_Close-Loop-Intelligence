# %% [markdown]
# # Paso 2: Obtencion y carga del conjunto de datos

# %%
#Realizamos la instalacion para ejecutar la conexion con Kaggle
# %pip install kaggle
# %pip install opendatasets
# Out:
# Requirement already satisfied: kaggle in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: bleach in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (0.1.15)
# Requirement already satisfied: packaging in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (26.0)
# Requirement already satisfied: protobuf in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (6.33.5)
# Requirement already satisfied: python-dateutil in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: tqdm in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (4.67.3)
# Requirement already satisfied: urllib3>=1.15.1 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle) (2.6.3)
# Requirement already satisfied: webencodings in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: six>=1.5 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from requests->kaggle) (2026.1.4)
# Note: you may need to restart the kernel to use updated packages.
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: tqdm in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from opendatasets) (4.67.3)
# Requirement already satisfied: kaggle in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from opendatasets) (2.0.0)
# Collecting click (from opendatasets)
#   Downloading click-8.3.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: bleach in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (6.3.0)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.15 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (0.1.15)
# Requirement already satisfied: packaging in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (26.0)
# Requirement already satisfied: protobuf in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (6.33.5)
# Requirement already satisfied: python-dateutil in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (2.9.0.post0)
# Requirement already satisfied: python-slugify in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (8.0.4)
# Requirement already satisfied: requests in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (2.32.5)
# Requirement already satisfied: urllib3>=1.15.1 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from kaggle->opendatasets) (2.6.3)
# Requirement already satisfied: webencodings in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from bleach->kaggle->opendatasets) (0.5.1)
# Requirement already satisfied: six>=1.5 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from python-dateutil->kaggle->opendatasets) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from requests->kaggle->opendatasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from requests->kaggle->opendatasets) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /workspaces/Proyecto_Final_Close-Loop-Intelligence/venv/lib/python3.11/site-packages (from requests->kaggle->opendatasets) (2026.1.4)
# Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Downloading click-8.3.1-py3-none-any.whl (108 kB)
# Installing collected packages: click, opendatasets
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [opendatasets]
# Successfully installed click-8.3.1 opendatasets-0.1.22
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import opendatasets as od
import sqlite3
import os
import glob

# %%
#Configuramos Nombres de Base de Datos
BD = 'BaseSQL.db'
csv_files = glob.glob('brazilian-ecommerce/*.csv')

conexion = sqlite3.connect(BD)

try:
    print(f"Iniciando migración de {len(csv_files)} archivos a la base de datos...")

    for archivo in csv_files:
        # Limpiamos el nombre para la tabla (sin extensión y sin caracteres raros)
        nombre_tabla = os.path.splitext(archivo)[0].replace(" ", "_").lower()

        # Cargamos el archivo a un DataFrame
        df = pd.read_csv(archivo)

        # 3. Guardar en la base de datos
        # index=False evita que se cree una columna extra para el índice de pandas
        df.to_sql(nombre_tabla, conexion, if_exists='replace', index=False)

        print(f"Cargado con éxito: {archivo} -> Tabla: {nombre_tabla}")

    print("\nProceso finalizado. Ahora puedes borrar los .csv originales si lo deseas.")

finally:
    conexion.close()
